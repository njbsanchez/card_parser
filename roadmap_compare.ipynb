# %%
import pandas as pd

# %%
df_1 = pd.read_csv("csv_outputs/dc_cards_2022-02-23.csv")
df_2 = pd.read_csv("csv_outputs/dc_cards_2021-12-16.csv")

# %%
# output the dataframe

df_1.head(5)
# Out:
#    Unnamed: 0                            title  \
# 0           1         Annual app certification
# 1           2          App performance toolkit
# 2           3                  App diagnostics
# 3           4  Bamboo Data Center Apps Program
# 4           5          Migrating nested groups
#
#                                          description       status  \
# 0  Data Center approved apps go through annual ar...     Released
# 1  Test the performance of your apps with our too...     Released
# 2  View a summary of the alerts that have been ra...     Released
# 3  Data Center approved apps go through rigorous ...     Released
# 4  Flatten your nested groups between AzureAD and...  Coming soon
#
#                category     date  \
# 0  Apps & extensibility     none
# 1  Apps & extensibility  Q4 2021
# 2  Apps & extensibility     none
# 3  Apps & extensibility  Q4 2021
# 4      Cloud migrations  Q1 2022
#
#                                             products
# 0  Jira Software, Confluence, Jira Service Manage...
# 1  Jira Software, Confluence, Jira Service Manage...
# 2                                     Bitbucket 5.9+
# 3                                             Bamboo
# 4  Jira Software, Jira Service Management, Conflu...

# %%
df_2.head(5)
# Out:
#    Unnamed: 0                            title  \
# 0           1         Annual app certification
# 1           2          App performance toolkit
# 2           3                  App diagnostics
# 3           4  Bamboo Data Center Apps Program
# 4           5          Migrating nested groups
#
#                                          description       status category  \
# 0  Data Center approved apps go through annual ar...      Shipped     none
# 1  Test the performance of your apps with our too...      Shipped     none
# 2  View a summary of the alerts that have been ra...      Shipped     none
# 3  Data Center approved apps go through rigorous ...  Coming soon     none
# 4  Flatten your nested groups between AzureAD and...       Future     none
#
#          date                                           products
# 0        none  Jira Software, Confluence, Jira Service Manage...
# 1        none  Jira Software, Confluence, Jira Service Manage...
# 2        none                                     Bitbucket 5.9+
# 3  Q3-Q4 2021                                             Bamboo
# 4  Q2-Q3 2022  Jira Software, Jira Service Management, Conflu...
